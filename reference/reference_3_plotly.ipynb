# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import plotly.express as px

# %%
# Demo Dataset for the practice : 
data_set_name = sns.get_dataset_names()

# %%
print(data_set_name)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df  =sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# !pip install "nbformat>=4.2.0"
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install notebook jupyterlab ipywidgets
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install notebook
# !pip install ipywidgets
# !pip install jupyterlab
# !pip install plotly --upgrade
# !pip install nbformat --upgrade
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Now we can make the dataset with the different graphs : 
fig  = px.box(df , y="sex")
fig.show()

# %%
# Box Plots with other parameters :  

fig  = px.box(df , x="variable_name" , y = "another_variable_from_the_column") # This makes two box plots in the same graph
fig =  px.box(df , x="time" , y="total_bill" , points="all") # This makes a dispersion type of cloud in the graph to show along with the box plot. 
# The dispersion shows the minimum and the maximum for the graphs.  
# we also can write the outliers instead of points ( that is the default parameter )

fig  = px.box(df , x = "column_name" , y="Column_name_2" , color = "color_column" , points="all" , title="Title for the graph" , hover_data=["column_name"]) # Color should be for the categorical column

# For the box plots we also can use the nothched = True to make the ntoched box plot .




fig  = px.strip(df , x = "column_name" , y = "column_name")
fig.show() # THis makes only the data points visible and we can use this to show the dispersion of the data.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Box Plots with other parameters :
# ----> 3 fig  = px.box(df , x="variable_name" , y = "another_variable_from_the_column") # This makes two box plots in the same graph
#       4 fig =  px.box(df , x="time" , y="total_bill" , points="all") # This makes a dispersion type of cloud in the graph to show along with the box plot.
#       5 # The dispersion shows the minimum and the maximum for the graphs.
#       6 # we also can write the outliers instead of points ( that is the default parameter )
#
# ...

# %%
### Histogram using plotly : 
fig  = px.histogram(df , x = "total_bill" , nbins=10)
fig.show()
fig  = px.histogram(data_frame_name  , x = "column_1" , histnorm  = "probability density") # Hisnorm shows the type of the graph we wanna see in the graph 
fig.update_layout(bargap = 0.2 )
fig.show()

# we can use the bargap for the bars to be near or far from the graph. 

# We canuse the hsitnorm=probability to get the histogram from the probability density.   we can also check the percent insted of probability density. 

# we can also make the histogram from the two variables :  

fig  = px.histogram(df , x = "" , color="")
fig.show()

# In here the x is the color and the numerical column is the x and the categorical column is the color. 
# we can also use the aggregate function insted of the default count :  

fig  = px.histogram(df , x="" , y="" , histfunc="avg")
fig.show()
# Insted of the average we also can use the other functions for the aggregate functions.

# For the patterns we can use the function as : 

fig  = px.histogram(df , x = "" , y="" , color="categorical variable" , pattern_shape="any categorical binary column")
fig.show()  # This makes the histogram visible with the cateogical part with the pattern in the histogram


# In histogram we also can add the text in the graph: 

fig  = px.histogram(df, x = "": , y="" , histfunc="" , nbins=10 , text_auto=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 fig  = px.histogram(df , x = "total_bill" , nbins=10)
#       3 fig.show()
# ----> 4 fig  = px.histogram(data_frame_name  , x = "column_1" , histnorm  = "probability density") # Hisnorm shows the type of the graph we wanna see in the graph
#       5 fig.update_layout(bargap = 0.2 )
#       6 fig.show()
#
# NameError: name 'data_frame_name' is not defined

# %%
# Line Charts : 

df = px.data.gapminder()

df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
fig = px.line(df , x = 'year' , y='lifeExp')
fig.show()

# %%
# We can use the color. with the category as well. Make the color with the categoires to make it distinguish. margers=True

# To make the graph 2 or mroe scatter plots we can make the connected scatter plot.  Two or more variables poloted with the line connecting them pregferably year or etc related to time

# for this just first make the data frame with the required columns 2 or more and then the code for the scatter plot be same :

# %%
# Scatter Plot using Plotly : 

df  = px.data.iris()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
fig  = px.scatter(df , x='sepal_width' , y = 'sepal_length')
fig.show()

# %%
# TO add the legend and other parameters we can use the code as  /: 
df = px.scatter(df , x='sepal_length' , y='sepal_width')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 # TO add the legend and other parameters we can use the code as  /:
# ----> 2 df = px.scatter(df , x='sepal_length' , y='sepal_width')
#
# ...

# %%
# TO make the violin Plot we can make the Graph as : 

fig = px.violin(df , y = "column_name"  )
fig.show()

# FOr the two variables :: 


fig  = px.violin(df , y="Column_name" , box=True , points="all")
# The points can be outliers as well this only shows the oitliers. 

# we can show  the voilin with the graph using the voilin parameter. 

fig  = px.violin(df , y='column_name' , color="categorical_variable" , violinmode="overlay" ,hover_data=df.columns)
fig.update_traces(quartilemethod="exclusive") # This is used to make the traces we also can make the inclusive for the applicaiton : 
fig.show()
