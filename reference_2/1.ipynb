# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df  = px.data.tips()

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# FOr showing the points in the map se can use the plotly and data shader : External libraries and they are not that much useful to make this heavy bulky maps

# %%
# make sun brust using plotly  : 

fig  = px.sunburst(data_frame=df , path=['smoker' , 'sex' , 'time'] , color='time' , color_discrete_sequence=px.colors.qualitative.Pastel , maxdepth=-1)

fig.show()

# %%
# Recing Bar Graph : Plotly :: 

# check the difference in plotly graph objects and plotly go and plotly express and make the code

import pandas as pd
import plotly
import plotly.io as pio
import plotly.graph_objects as go

import warnings

# %%
# We also can make the animated grpah using plotly bar plot animated we have to make the dict from the sections and then iterate them one eky value pair each time

# Using that make animated graph for the same :
